# %%
import pandas as pd
st = pd.read_csv("D:\practice\healthcare-dataset-stroke-data.csv",index_col=0)
print(st)
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
st = pd.read_csv("D:\practice\healthcare-dataset-stroke-data.csv")
st_first = st.loc[0:10]
st_first.plot(x = 'age',y = 'bmi')
plt.show()

# %%
import pandas as pd
st = pd.read_csv("D:\practice\healthcare-dataset-stroke-data.csv")
st_first = st.loc[0:10]
st['bmi'].plot(kind='hist')
plt.show()

# %%
connection = pyodbc.connect('Driver={SQL Server};'
                            'Server=server_name;'
                            'Database=database_name;'
                            'Trusted_Connection=yes;')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 connection = pyodbc.connect('Driver={SQL Server};'
#       2                             'Server=server_name;'
#       3                             'Database=database_name;'
#       4                             'Trusted_Connection=yes;')
#
# NameError: name 'pyodbc' is not defined

# %%
import pandas as pd
st = pd.read_csv("D:\practice\healthcare-dataset-stroke-data.csv",index_col=0)
st_group = st.groupby('age')
st_group.first()
# Out:
#        gender  hypertension  heart_disease ever_married      work_type  \
# age
# 0.08   Female             0              0           No       children
# 0.16     Male             0              0           No       children
# 0.24     Male             0              0           No       children
# 0.32   Female             0              0           No       children
# 0.40     Male             0              0           No       children
# ...       ...           ...            ...          ...            ...
# 78.00  Female             0              0          Yes        Private
# 79.00  Female             1              0          Yes  Self-employed
# 80.00    Male             0              1          Yes        Private
# 81.00    Male             0              0          Yes        Private
# 82.00    Male             0              1          Yes        Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# age
# ...

# %%
count = st_group.size()
# Out:
# age
# 0.08       2
# 0.16       3
# 0.24       5
# 0.32       5
# 0.40       2
#         ...
# 78.00    102
# 79.00     85
# 80.00     70
# 81.00     60
# 82.00     56
# Length: 104, dtype: int64

# %%
count.plot.bar(x='age',rot=1)
# Out:
# <Axes: xlabel='age'>
